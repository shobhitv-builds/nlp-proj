# %%
# imports
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split
import numpy as np

# allow plots to appear directly in the notebook
# %matplotlib inline

# %%
df = pd.read_csv("../data/regression-task/master-regression-dataset.csv", sep=';', lineterminator='\n')
df = df.drop(labels=['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'High', 'Low', 'Close', 'Open', 'Volume', 'Timestamp', 'Momentum'], axis=1)
df.head()
# Out:
#       Delta  Volatility  AvgVolatility  positive_sentiment
# 0 -0.631500    0.000000            0.0            0.469450
# 1  0.418999   -0.005044            0.0            0.423330
# 2  1.206997   -0.042437            0.0            0.486872
# 3  0.843002    0.005326            0.0            0.505960
# 4 -0.531502   -0.000792            0.0            0.433893

# %%
sns.pairplot(df, x_vars=df.columns, y_vars='Delta')

# %%
features = ['Volatility', 'AvgVolatility', 'Momentum', 'positive_sentiment']
X = df[features]
y = df['Delta']
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()
